# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnu1001/aqi-ml-prediction/blob/main/Delhi_AQI_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error #RMSE

from sklearn.preprocessing import MinMaxScaler # for ranged values
from keras.preprocessing.sequence import TimeseriesGenerator

#Importing the necessary components to define our model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM # for precidtion
from keras.layers import Dropout
from keras.optimizers import Adam

from keras.utils import plot_model

#///////////////////////////////////////////////////////////////////////////////

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
from IPython.display import HTML,display

warnings.filterwarnings("ignore")

# %%
#Read the daily city-wise data
df = pd.read_csv("city_day.csv", parse_dates=True)

df['Date'] = pd.to_datetime(df['Date'])

#Keeping only the columns needed
#City, Date, AQI
df = df[['City','Date','AQI']]
delhi = df[df['City'] == 'Delhi']

delhi.drop(['City'],axis=1,inplace = True)
delhi.set_index('Date', inplace = True)

delhi
# Out:
#               AQI
# Date
# 2015-01-01  472.0
# 2015-01-02  454.0
# 2015-01-03  143.0
# 2015-01-04  319.0
# 2015-01-05  325.0
# ...           ...
# 2020-06-27  112.0
# 2020-06-28  196.0
# 2020-06-29  233.0
# 2020-06-30  114.0
# 2020-07-01  101.0
#
# [2009 rows x 1 columns]

# %%
#Fill NULL DATA
delhi['AQI'].fillna(method = 'bfill',inplace = True)

#Taking monthly average
delhi = delhi.astype('float64')
delhi = delhi.resample(rule='MS').mean()

ax = delhi[['AQI']].plot(figsize=(12,8),grid=True,lw=2,color='Red')
ax.autoscale(enable=True, axis='both', tight=True)
                                                                                           
#Importing seasonal_decompose and mean_squared_error

delhi_AQI=delhi['AQI']
result = seasonal_decompose(delhi_AQI,model='multiplicative')
result.plot();

# %%
#Splitting the training and testing data

train = delhi[:48]
test = delhi[48:61]

type(train)

#print("Shape of train data:" + str(train.array.shape))
#print("Shape of test data:" + str(test.array.shape))

print("Shape of train data: " + str(train.shape))
print("Shape of test data: " + str(test.shape))

#train_arr=np.expand_dims(train, axis=1)
#test_arr=np.expand_dims(test, axis=1)

train_arr = train
test_arr = test

train_arr
# Out:
# Shape of train data: (48, 1)
# Shape of test data: (13, 1)
#                    AQI
# Date
# 2015-01-01  342.290323
# 2015-02-01  327.928571
# 2015-03-01  256.064516
# 2015-04-01  305.266667
# 2015-05-01  348.580645
# 2015-06-01  258.333333
# 2015-07-01  200.290323
# 2015-08-01  218.064516
# 2015-09-01  225.300000
# 2015-10-01  325.000000
# 2015-11-01  405.033333
# 2015-12-01  355.322581
# 2016-01-01  441.903226
# 2016-02-01  312.448276
# 2016-03-01  230.096774
# 2016-04-01  290.666667
# 2016-05-01  268.354839
# 2016-06-01  243.733333
# 2016-07-01  165.935484
# 2016-08-01  147.419355
# 2016-09-01  218.700000
# 2016-10-01  411.064516
# 2016-11-01  474.833333
# 2016-12-01  409.290323
# 2017-01-01  354.193548
# 2017-02-01  343.928571
# 2017-03-01  282.258065
# 2017-04-01  316.800000
# 2017-05-01  315.419355
# 2017-06-01  143.633333
# 2017-07-01   67.161290
# 2017-08-01   67.645161
# 2017-09-01  114.666667
# 2017-10-01  284.161290
# 2017-11-01  406.733333
# 2017-12-01  337.129032
# 2018-01-01  349.741935
# 2018-02-01  289.178571
# 2018-03-01  234.129032
# 2018-04-01  245.533333
# 2018-05-01  235.322581
# 2018-06-01  224.366667
# 2018-07-01  112.419355
# 2018-08-01  122.064516
# 2018-09-01  121.933333
# 2018-10-01  290.419355
# 2018-11-01  367.066667
# 2018-12-01  400.387097

# %%
#Preprocessing the dataset

# Importing MinMaxScaler from sklearn.preprocessing
scaler = MinMaxScaler()

scaler.fit(train_arr)

scaled_train = scaler.transform(train_arr)
scaled_test = scaler.transform(test_arr)

#Defining our time series generator that would be used to parse data into the model

#Importing TimeseriesGenerator from keras.preprocessing.sequence

n_input = 12
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.67487834 0.63964965 0.46337057 0.58406109 0.6903082  0.46893587
#  0.32655914 0.37015839 0.38790668 0.63246601 0.82878394 0.70684585]
# Predict this y:
#  [[0.91922402]]

# %%
# #Importing the necessary components to define our model
# #Imported in cell 1

# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import LSTM
# from keras.layers import Dropout
# from keras.optimizers import Adam

# defining the stacked LSTM model
model = Sequential(name = 'LSTM-Model')
model.add(LSTM(32, activation='relu', return_sequences = True, input_shape=(n_input, n_features),name = "LSTM_1"))
#model.add(LSTM(100, activation='relu', return_sequences = True,name = "LSTM_2"))
#model.add(Dropout(0.2))
model.add(LSTM(32, activation='relu',name = "LSTM_2"))
#model.add(Dropout(0.2))
#model.add(Dense(8))
model.add(Dense(1,name = "DENSE_1"))
model.compile(optimizer= 'adam',  loss='mse')

model.summary()

#Plotting the layer structure
from keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True,rankdir="TB",dpi=96)
# Out:
# Model: "LSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_1 (LSTM)               (None, 12, 32)            4352
#
#  LSTM_2 (LSTM)               (None, 32)                8320
#
#  DENSE_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,705
# Trainable params: 12,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plotting the layer structure
#Importing plot_model form keras.utils

plot_model(model,show_shapes=True,show_layer_names=True,rankdir="TB",dpi=96)

#Fitting our model
model.fit_generator(generator,epochs=200)

#plotting the loss vs #of epoch 
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

#Predicting using our model on the testing dataset
test_predictions = []

first_batch = scaled_train[-n_input:]
current_batch = first_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
      
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred) 
    
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

test_predictions = scaler.inverse_transform(test_predictions)

print(test_predictions.shape)
print(test_arr.shape)

test_arr['Predictions'] = test_predictions

#Plotting the true values vs predicted values on testing dataset
plt.plot(test_arr['AQI'],label = 'AQI')
plt.plot(test_arr['Predictions'],label = 'Predictions')

plt.legend()
# Out:
# Epoch 1/200
# 36/36 [==============================] - 3s 9ms/step - loss: 0.2359
# Epoch 2/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0833
# Epoch 3/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0797
# Epoch 4/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0793
# Epoch 5/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0761
# Epoch 6/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0700
# Epoch 7/200
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0721
# Epoch 8/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0741
# Epoch 9/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0686
# Epoch 10/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0664
# Epoch 11/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0664
# Epoch 12/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0788
# Epoch 13/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0717
# Epoch 14/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0612
# Epoch 15/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0589
# Epoch 16/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0569
# Epoch 17/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0547
# Epoch 18/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0511
# Epoch 19/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0491
# Epoch 20/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0521
# Epoch 21/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0443
# Epoch 22/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0436
# Epoch 23/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0430
# Epoch 24/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0525
# Epoch 25/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0481
# Epoch 26/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0454
# Epoch 27/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0442
# Epoch 28/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0371
# Epoch 29/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0402
# Epoch 30/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0409
# Epoch 31/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0386
# Epoch 32/200
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0437
# Epoch 33/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0378
# Epoch 34/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0307
# Epoch 35/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0308
# Epoch 36/200
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0278
# Epoch 37/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0313
# Epoch 38/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0319
# Epoch 39/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0305
# Epoch 40/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0319
# Epoch 41/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0372
# Epoch 42/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0309
# Epoch 43/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0291
# Epoch 44/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0245
# Epoch 45/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0251
# Epoch 46/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0291
# Epoch 47/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0289
# Epoch 48/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0298
# Epoch 49/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0248
# Epoch 50/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0249
# Epoch 51/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0229
# Epoch 52/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0290
# Epoch 53/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0286
# Epoch 54/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0245
# Epoch 55/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0282
# Epoch 56/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0298
# Epoch 57/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0245
# Epoch 58/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0229
# Epoch 59/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0219
# Epoch 60/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0247
# Epoch 61/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0247
# Epoch 62/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0213
# Epoch 63/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0196
# Epoch 64/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0298
# Epoch 65/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0242
# Epoch 66/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0210
# Epoch 67/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0212
# Epoch 68/200
# 36/36 [==============================] - 1s 19ms/step - loss: 0.0189
# Epoch 69/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0410
# Epoch 70/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0261
# Epoch 71/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0228
# Epoch 72/200
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0213
# Epoch 73/200
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0214
# Epoch 74/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0202
# Epoch 75/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0195
# Epoch 76/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0196
# Epoch 77/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0208
# Epoch 78/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0207
# Epoch 79/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0184
# Epoch 80/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0207
# Epoch 81/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0275
# Epoch 82/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0171
# Epoch 83/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0207
# Epoch 84/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0184
# Epoch 85/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0201
# Epoch 86/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0244
# Epoch 87/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0169
# Epoch 88/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0176
# Epoch 89/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0188
# Epoch 90/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0167
# Epoch 91/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0184
# Epoch 92/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0147
# Epoch 93/200
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0204
# Epoch 94/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0158
# Epoch 95/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0181
# Epoch 96/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0172
# Epoch 97/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 98/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0193
# Epoch 99/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0160
# Epoch 100/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 101/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0150
# Epoch 102/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0162
# Epoch 103/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0183
# Epoch 104/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0189
# Epoch 105/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0213
# Epoch 106/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0169
# Epoch 107/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0161
# Epoch 108/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0172
# Epoch 109/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0159
# Epoch 110/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0137
# Epoch 111/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0120
# Epoch 112/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0294
# Epoch 113/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0150
# Epoch 114/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0142
# Epoch 115/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0135
# Epoch 116/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0122
# Epoch 117/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0150
# Epoch 118/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0128
# Epoch 119/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0143
# Epoch 120/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0106
# Epoch 121/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0106
# Epoch 122/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0136
# Epoch 123/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0122
# Epoch 124/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0124
# Epoch 125/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0130
# Epoch 126/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 127/200
# 36/36 [==============================] - 1s 17ms/step - loss: 0.0115
# Epoch 128/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0085
# Epoch 129/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0193
# Epoch 130/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0128
# Epoch 131/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0123
# Epoch 132/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0144
# Epoch 133/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0123
# Epoch 134/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0126
# Epoch 135/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0109
# Epoch 136/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0124
# Epoch 137/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0103
# Epoch 138/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0124
# Epoch 139/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0102
# Epoch 140/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0104
# Epoch 141/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 142/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0100
# Epoch 143/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 144/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 145/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0107
# Epoch 146/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 147/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0144
# Epoch 148/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 149/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0149
# Epoch 150/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0134
# Epoch 151/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0105
# Epoch 152/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0108
# Epoch 153/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0101
# Epoch 154/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0102
# Epoch 155/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 156/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0139
# Epoch 157/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0106
# Epoch 158/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0115
# Epoch 159/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0101
# Epoch 160/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0110
# Epoch 161/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0102
# Epoch 162/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 163/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0103
# Epoch 164/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0119
# Epoch 165/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0107
# Epoch 166/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0094
# Epoch 167/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0121
# Epoch 168/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0091
# Epoch 169/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0120
# Epoch 170/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0090
# Epoch 171/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 172/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0095
# Epoch 173/200
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 174/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0118
# Epoch 175/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0099
# Epoch 176/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0093
# Epoch 177/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0095
# Epoch 178/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0083
# Epoch 179/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0100
# Epoch 180/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0131
# Epoch 181/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0103
# Epoch 182/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 183/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 184/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0095
# Epoch 185/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0090
# Epoch 186/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0093
# Epoch 187/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0098
# Epoch 188/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 189/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 190/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0085
# Epoch 191/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0081
# Epoch 192/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0086
# Epoch 193/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 194/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0133
# Epoch 195/200
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0078
# Epoch 196/200
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 197/200
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0085
# Epoch 198/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0109
# Epoch 199/200
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0064
# Epoch 200/200
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0071
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# (13, 1)
# (13, 1)

# %%
#Calculating the root mean squared error on the testing dataset
RMSE_test = np.sqrt(mean_squared_error(test_arr['AQI'],test_arr['Predictions']))
print('RMSE on the testing dataset = ',RMSE_test)
print('India_AQI=',test_arr['AQI'].mean())

#Predicting using our model on the training dataset
train_predictions = []

first_eval_batch = scaled_train[:n_input]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(train-n_input)):
      
    current_pred = model.predict(current_batch)[0]
    train_predictions.append(current_pred) 
    
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

train_predictions = scaler.inverse_transform(train_predictions)

print(train_predictions.shape)
print(train_arr.shape)

train_arr['Predictions'] = train_predictions
# Out:
# RMSE on the testing dataset =  31.094290860437123
# India_AQI= 238.0504608294931
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# (48, 1)
# (48, 1)

# %%
#Plotting the true values vs predicted values on training dataset
plt.figure(figsize=(12,8))
plt.plot#Plo(train_arr['AQI'],label = 'AQI')
plt.plot(train_arr['Predictions'],label = 'Predictions')
plt.legend()

#Calculating the root mean squared error on the testing dataset
RMSE_train =np.sqrt(mean_squared_error(train_arr['AQI'],train_arr['Predictions']))
print('RMSE on the training dataset = ',RMSE_train)
print('India_AQI=',train_arr['AQI'].mean())

delhi_arr = delhi
scaled_delhi = scaler.transform(delhi_arr)

delhi_arr
# Out:
# RMSE on the training dataset =  54.31217507572275
# India_AQI= 275.1711046334552
#                    AQI
# Date
# 2015-01-01  342.290323
# 2015-02-01  327.928571
# 2015-03-01  256.064516
# 2015-04-01  305.266667
# 2015-05-01  348.580645
# ...                ...
# 2020-03-01  135.838710
# 2020-04-01  113.000000
# 2020-05-01  148.645161
# 2020-06-01  125.733333
# 2020-07-01  101.000000
#
# [67 rows x 1 columns]
